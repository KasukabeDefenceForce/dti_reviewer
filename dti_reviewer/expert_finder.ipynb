# %%
import pandas as pd
import sklearn

# %%
authors = pd.read_hdf('/home/abhinav/workspace/code/expert-finder/LSPO_v1.h5')

# %%
def combine_texts(group):
    combined = (group['title'].fillna('') + ' ' + group['abstract'].fillna('')).str.strip()
    return pd.Series({
        'text': ' '.join(combined)
    })

combined_texts = authors.groupby('@path').apply(combine_texts).reset_index()
# Out:
# /tmp/ipykernel_254394/2125986324.py:7: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   combined_texts = authors.groupby('@path').apply(combine_texts).reset_index()

# %%
combined_texts
# Out:
#                        @path  \
# 0       /0000-0001-5000-0736
# 1       /0000-0001-5000-1341
# 2       /0000-0001-5000-3793
# 3       /0000-0001-5000-5991
# 4       /0000-0001-5000-6265
# ...                      ...
# 125481  /0000-0003-4999-3106
# 125482  /0000-0003-4999-5734
# 125483  /0000-0003-4999-5822
# 125484  /0000-0003-4999-5996
# 125485  /0000-0003-4999-6956
#
#                                                      text
# 0       Tectonothermal analysis of high-temperature my...
# 1       New description of gradual substitution of gra...
# 2       Analytical Models of the Performance of C-V2X ...
# 3       Chemical aging and the hydrophobic-to-hydrophi...
# 4       Pollution and economic development: an empiric...
# ...                                                   ...
# 125481  Phase-space dynamics of opposition control in ...
# 125482  Electromagnetic scattering from a multilayered...
# 125483  Invited Article: Broadband highly efficient di...
# 125484  A network approach to discerning the identitie...
# 125485  Microelectromechanical delay lines with slow s...
#
# [125486 rows x 2 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english', max_features=10000)
tfidf_matrix = vectorizer.fit_transform(combined_texts['text'])

# %%
query = "Type 1a Supernovae"
query_vec = vectorizer.transform([query])  # shape: (1, num_terms)

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarities = cosine_similarity(query_vec, tfidf_matrix).flatten()  # shape: (num_authors,)

# %%
top_indices = similarities.argsort()[::-1][:25]
top_authors = combined_texts.iloc[top_indices]
top_authors['similarity'] = similarities[top_indices]
# Out:
# /tmp/ipykernel_254394/3799886919.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_authors['similarity'] = similarities[top_indices]

# %%
top_authors
# Out:
#                        @path  \
# 110187  /0000-0003-2544-4516
# 58012   /0000-0002-4173-193X
# 20659   /0000-0001-8257-3512
# 86568   /0000-0002-8743-3292
# 119288  /0000-0003-4016-9428
# 74401   /0000-0002-6762-5254
# 114763  /0000-0003-3270-6844
# 35245   /0000-0002-0564-1101
# 69042   /0000-0002-5920-1478
# 90847   /0000-0002-9436-8871
# 38273   /0000-0002-1051-6014
# 107967  /0000-0003-2180-6735
# 33655   /0000-0002-0317-5063
# 6023    /0000-0001-5941-6981
# 26174   /0000-0001-9126-3532
# 51921   /0000-0002-3211-303X
# 66290   /0000-0002-5478-2293
# 58832   /0000-0002-4299-7561
# 74315   /0000-0002-6752-0436
# 87753   /0000-0002-8929-250X
# 80919   /0000-0002-7815-1496
# 60933   /0000-0002-4642-105X
# 57808   /0000-0002-4145-1516
# 58767   /0000-0002-4289-7528
# 3354    /0000-0001-5525-089X
#
#                                                      text  similarity
# 110187  Optimal Classification and Outlier Detection f...    0.375800
# 58012   Synthesis, crystal structure and computational...    0.349692
# 20659   Supernovae and extragalactic astronomy with la...    0.336378
# 86568   Synthesis, X-Ray diffraction, theoretical and ...    0.331608
# 119288  Sea-level constraints on the amplitude and sou...    0.315058
# 74401   hERG 1b is critical for human cardiac repolari...    0.309603
# 114763  Revealing Dusty Supernovae in High-redshift (U...    0.299480
# 35245   Direct determination of the hubble parameter u...    0.296621
# 69042   Direct determination of the hubble parameter u...    0.287050
# 90847   Estimating weak lensing convergence correlatio...    0.278911
# 38273   Mechanism of translation control of the altern...    0.275349
# 107967  Membrane protein sequestering by ionic protein...    0.261712
# 33655   A neutron-star-driven X-ray flash associated w...    0.259384
# 6023    Simulations of magnetized multiphase galactic ...    0.258072
# 26174   An iterative PS-InSAR method for the analysis ...    0.250225
# 51921   PUSHing Core-collapse Supernovae to Explosions...    0.244005
# 66290   Tidal Streams of Intracluster Light Using N-bo...    0.240987
# 58832   The GPR139 reference agonists 1a and 7c, and t...    0.235622
# 74315   Collaborating CPU and GPU for large-scale high...    0.234221
# 87753   A deep learning approach to cosmological dark ...    0.221668
# 80919   Thermonuclear (Type Ia) Supernovae and Progeni...    0.219572
# 60933   Immunological responses following administrati...    0.209947
# 57808   The RAG2 C terminus suppresses genomic instabi...    0.206691
# 58767   Effect of fission rate on the microstructure o...    0.191267
# 3354    Visualization of the local contribution to the...    0.190241

# %%
# Sample 3 DOIs per top author
author_info = (
    authors[['@path', 'author']] #, 'doi']
    #.dropna(subset=['doi'])  # Remove missing DOIs
    .groupby('@path')
    .agg({
        'author': 'first'
        #'doi': lambda x: list(x.unique())[:3]  # Sample up to 3 unique DOIs
    })
    .reset_index()
)

# %%
results = top_authors.merge(author_info, on='@path', how='left')
results = results[['@path', 'author', 'similarity']]

# %%
results
# Out:
#                    @path                   author  similarity
# 0   /0000-0003-2544-4516         Williamson, Marc    0.375800
# 1   /0000-0002-4173-193X          Hoffmann, Józef    0.349692
# 2   /0000-0001-8257-3512           Kankare, Erkki    0.336378
# 3   /0000-0002-8743-3292      Shihab, Mehdi Salih    0.331608
# 4   /0000-0003-4016-9428          Kopp, Robert E.    0.315058
# 5   /0000-0002-6762-5254          Jones, David K.    0.309603
# 6   /0000-0003-3270-6844              Ma, Zhiyuan    0.299480
# 7   /0000-0002-0564-1101             Potashov, M.    0.296621
# 8   /0000-0002-5920-1478             Baklanov, P.    0.287050
# 9   /0000-0002-9436-8871              Mitra, Ayan    0.278911
# 10  /0000-0002-1051-6014             Specchia, V.    0.275349
# 11  /0000-0003-2180-6735   van den Bogaart, Geert    0.261712
# 12  /0000-0002-0317-5063         Sauer, Daniel N.    0.259384
# 13  /0000-0001-5941-6981          Iffrig, Olivier    0.258072
# 14  /0000-0001-9126-3532               Nemati, S.    0.250225
# 15  /0000-0002-3211-303X          Curtis, Sanjana    0.244005
# 16  /0000-0002-5478-2293         Frey, Lucille H.    0.240987
# 17  /0000-0002-4299-7561        Gloriam, David E.    0.235622
# 18  /0000-0002-6752-0436           Wang, Yongxian    0.234221
# 19  /0000-0002-8929-250X  Escamilla-Rivera, Celia    0.221668
# 20  /0000-0002-7815-1496        DeGrendele, C. J.    0.219572
# 21  /0000-0002-4642-105X          Grubor-Bauk, B.    0.209947
# 22  /0000-0002-4145-1516            Skok, Jane A.    0.206691
# 23  /0000-0002-4289-7528        Schulthess, Jason    0.191267
# 24  /0000-0001-5525-089X            Calder, A. C.    0.190241

# %%
name_variations = (
    authors[['@path', 'author']]
    .dropna()
    .groupby('@path')['author']
    .apply(lambda names: list(sorted(set(names))))
    .reset_index()
    .rename(columns={'author': 'name_variations'})
)

# %%
results = results.merge(name_variations, on='@path', how='left')

# %%
results
# Out:
#                    @path                   author  similarity  \
# 0   /0000-0003-2544-4516         Williamson, Marc    0.375800
# 1   /0000-0002-4173-193X          Hoffmann, Józef    0.349692
# 2   /0000-0001-8257-3512           Kankare, Erkki    0.336378
# 3   /0000-0002-8743-3292      Shihab, Mehdi Salih    0.331608
# 4   /0000-0003-4016-9428          Kopp, Robert E.    0.315058
# 5   /0000-0002-6762-5254          Jones, David K.    0.309603
# 6   /0000-0003-3270-6844              Ma, Zhiyuan    0.299480
# 7   /0000-0002-0564-1101             Potashov, M.    0.296621
# 8   /0000-0002-5920-1478             Baklanov, P.    0.287050
# 9   /0000-0002-9436-8871              Mitra, Ayan    0.278911
# 10  /0000-0002-1051-6014             Specchia, V.    0.275349
# 11  /0000-0003-2180-6735   van den Bogaart, Geert    0.261712
# 12  /0000-0002-0317-5063         Sauer, Daniel N.    0.259384
# 13  /0000-0001-5941-6981          Iffrig, Olivier    0.258072
# 14  /0000-0001-9126-3532               Nemati, S.    0.250225
# 15  /0000-0002-3211-303X          Curtis, Sanjana    0.244005
# 16  /0000-0002-5478-2293         Frey, Lucille H.    0.240987
# 17  /0000-0002-4299-7561        Gloriam, David E.    0.235622
# 18  /0000-0002-6752-0436           Wang, Yongxian    0.234221
# 19  /0000-0002-8929-250X  Escamilla-Rivera, Celia    0.221668
# 20  /0000-0002-7815-1496        DeGrendele, C. J.    0.219572
# 21  /0000-0002-4642-105X          Grubor-Bauk, B.    0.209947
# 22  /0000-0002-4145-1516            Skok, Jane A.    0.206691
# 23  /0000-0002-4289-7528        Schulthess, Jason    0.191267
# 24  /0000-0001-5525-089X            Calder, A. C.    0.190241
#
#                      name_variations
# 0                 [Williamson, Marc]
# 1                  [Hoffmann, Józef]
# 2                   [Kankare, Erkki]
# 3              [Shihab, Mehdi Salih]
# 4                  [Kopp, Robert E.]
# 5                  [Jones, David K.]
# 6                      [Ma, Zhiyuan]
# 7   [Potashov, M., Potashov, M. Sh.]
# 8    [Baklanov, P., Baklanov, P. V.]
# 9                      [Mitra, Ayan]
# 10                    [Specchia, V.]
# 11          [van den Bogaart, Geert]
# 12  [Sauer, D. N., Sauer, Daniel N.]
# 13                 [Iffrig, Olivier]
# 14                      [Nemati, S.]
# 15                 [Curtis, Sanjana]
# 16                [Frey, Lucille H.]
# 17               [Gloriam, David E.]
# 18                  [Wang, Yongxian]
# 19         [Escamilla-Rivera, Celia]
# 20               [DeGrendele, C. J.]
# 21                 [Grubor-Bauk, B.]
# 22                   [Skok, Jane A.]
# 23               [Schulthess, Jason]
# 24  [Calder, A. C., Calder, Alan C.]
